# %% [markdown]
# ####  1.1 import libs, opencv, numpy and pyplot

# %% [markdown]
# #### 1.2 read and display image, check the basic image information(width, height. channel number), get the pixel value at (100, 200)

# %%
#### try to use pyplot and opencv both to display image

# %% [markdown]
# ##### 1.3 draw a circle with the central point at the coordinate of (50, 55) and radius of 15, and display and save this image

# %% [markdown]
# #### 1.4 convert this saved image at grayscale level and display it

# %% [markdown]
# #### 1.5 show the histogram of the grayscale image

# %% [markdown]
# #### 1.6 use Otsu's threshold to calculate the threshold value and display the segmented image

# %% [markdown]
# #### 1.7 calculate the total area of the objects in this image

# %% [markdown]
# #### 1.8 count the number of the objects, calculate the areas and draw central points for each object (objects  including background), display the final image
